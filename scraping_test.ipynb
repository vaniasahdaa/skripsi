# %% [markdown]
# <a href="https://colab.research.google.com/github/vaniasahdaa/skripsi/blob/main/scraping_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import csv

# %% [markdown]
# ## Install App Store Scraper

# %%
pip install app-store-scraper

# %%
from app_store_scraper import AppStore
from pprint import pprint
import datetime

start_date = datetime.datetime(2023, 9, 1)
end_date = datetime.datetime(2023, 10, 31)

telegram_scrape = AppStore(country="id", app_name="telegram-messenger")

telegram_scrape.review(how_many=100)

filtered_reviews = [review for review in telegram_scrape.reviews if start_date <= review['date'] <= end_date]

pprint(telegram_scrape.reviews)
pprint(telegram_scrape.reviews_count)
# Out:
# [{'date': datetime.datetime(2020, 8, 6, 20, 0, 32),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'telegram, can you update a stories fiture?? 🥺',
#   'title': 'stories',
#   'userName': 'kayla azz'},
#  {'date': datetime.datetime(2020, 2, 7, 12, 33, 36),
#   'isEdited': False,
#   'rating': 4,
#   'review': 'Bagus sih saya suka sekali, tapi alangkah lbh bagus jika ada '
#             'fitur free call group:(( tolong tambahin yashhh thanks❤️',
#   'title': 'Kritik saran',
#   'userName': 'emjecantik'},
#  {'date': datetime.datetime(2021, 4, 21, 17, 3, 37),
#   'isEdited': False,
#   'rating': 3,
#   'review': 'Kenapa gabisa login?? Harus proxy blablabalaa\n'
#             'Tolong telegram bisa login lagi dong aku bosan inii',
#   'title': 'Trouble',
#   'userName': 'disnkandiska'},
#  {'date': datetime.datetime(2020, 8, 16, 4, 49, 13),
#   'isEdited': False,
#   'rating': 1,
#   'review': 'gak mau masuk padahal dah gua masukin no gua tapi tetep aj gk di '
# ...

# %% [markdown]
# ## Array to CSV

# %%
data = [
    {'date': datetime.datetime(2020, 8, 6, 20, 0, 32),
  'isEdited': False,
  'rating': 4,
  'review': 'telegram, can you update a stories fiture?? 🥺',
  'title': 'stories',
  'userName': 'kayla azz'},
 {'date': datetime.datetime(2020, 2, 7, 12, 33, 36),
  'isEdited': False,
  'rating': 4,
  'review': 'Bagus sih saya suka sekali, tapi alangkah lbh bagus jika ada '
            'fitur free call group:(( tolong tambahin yashhh thanks❤️',
  'title': 'Kritik saran',
  'userName': 'emjecantik'},
 {'date': datetime.datetime(2021, 4, 21, 17, 3, 37),
  'isEdited': False,
  'rating': 3,
  'review': 'Kenapa gabisa login?? Harus proxy blablabalaa\n'
            'Tolong telegram bisa login lagi dong aku bosan inii',
  'title': 'Trouble',
  'userName': 'disnkandiska'},
 {'date': datetime.datetime(2020, 8, 16, 4, 49, 13),
  'isEdited': False,
  'rating': 1,
  'review': 'gak mau masuk padahal dah gua masukin no gua tapi tetep aj gk di '
            'sms',
  'title': 'gk dikasih code',
  'userName': 'bacotttttttt'},
 {'date': datetime.datetime(2020, 12, 16, 7, 45, 25),
  'isEdited': False,
  'rating': 5,
  'review': 'Gausah ditambahin fitur story, telegram itu cocok buat yg mau lbh '
            'secure dan private aja sih. Udh cukup juga bisa nonton film dll '
            'disini. Kalo mau story alay di WA atau Instagram.',
  'title': '😉',
  'userName': 'anissanova'},
 {'date': datetime.datetime(2021, 4, 21, 11, 52, 57),
  'isEdited': False,
  'rating': 1,
  'review': 'Tolong segera diperbaiki, setelah update malah ga bisa masuk ke '
            'telegram. Tertulis tidak ada connection dan ada pilihan untuk '
            'menggunakan vpn',
  'title': 'Not connection',
  'userName': 'Acien24'},
 {'date': datetime.datetime(2020, 8, 9, 15, 1, 52),
  'isEdited': False,
  'rating': 5,
  'review': 'Kak tolong dong buat Snap Telegram/Status Telegram (ST) masa iya '
            'ad kontak,ad yg ngechat tp gaada viewers😭👍🏻',
  'title': 'ST',
  'userName': 'mutiarazrgn'},
 {'date': datetime.datetime(2021, 5, 3, 15, 14, 47),
  'isEdited': False,
  'rating': 3,
  'review': 'saya install ulang telegram tapi kenapa gabisa login? malah harus '
            'pake proxy proxy itu?  tolong dong ini gimana',
  'title': 'tolong dibaca',
  'userName': 'Indah Viara'},
 {'date': datetime.datetime(2020, 12, 11, 9, 13, 39),
  'isEdited': False,
  'rating': 3,
  'review': 'Tolong pihak tele GUA DH MASUKIN NOMOR TAPI SMS NYA MANA💔😭',
  'title': 'Ga ke ke kirim sms',
  'userName': 'Sulake komsol'},
 {'date': datetime.datetime(2021, 4, 25, 12, 37, 25),
  'isEdited': False,
  'rating': 1,
  'review': 'KOK GBISA LOGIN ANYENK 😭😭😭',
  'title': 'nyet',
  'userName': 'cooooooottttt'},
 {'date': datetime.datetime(2021, 1, 5, 12, 40, 27),
  'isEdited': False,
  'rating': 3,
  'review': 'Buat yang udah masukin no telp tapi kode nya ga di kasih,coba '
            'tungguin 5-15 menit karena kadang kode nya telat gitu,tapi kalo '
            'udah 30 menit kode nya tetep ga di kasih mending apus aja dulu '
            'telegram nya terus donwoald lagi dan baru login,sama sama',
  'title': 'Tips',
  'userName': 'Brigitha Priscilla'},
 {'date': datetime.datetime(2021, 2, 10, 7, 37, 36),
  'isEdited': False,
  'rating': 3,
  'review': 'Gw udh pernah pake..trs keapus. Abis di download lagi dikasih '
            'nomer telpnya ga di kirimin smsnya..di email pun ga dijwb lagi.',
  'title': 'Ga bisa',
  'userName': '💫⭐️🌟✨Star Fam'},
 {'date': datetime.datetime(2021, 4, 21, 7, 30, 23),
  'isEdited': False,
  'rating': 1,
  'review': 'Gak bisa login aneh banget pdhl jaringan baik baik aja',
  'title': 'Gak bisa login',
  'userName': 'kevinka2505'},
 {'date': datetime.datetime(2021, 4, 21, 0, 51, 50),
  'isEdited': False,
  'rating': 4,
  'review': 'Awalnya vidio tidak bisa terdownload, habis itu saya unistal, '
            'terus instal kembali, lalu tidak bisa login karena tidak ada '
            'jaringan. Padahal sy sudah aktifkan data seluler dan coba '
            'sambungkan wifi juga. Huft',
  'title': 'Telegram tidak bisa login',
  'userName': 'chywa21'},
 {'date': datetime.datetime(2020, 11, 5, 13, 3, 8),
  'isEdited': False,
  'rating': 5,
  'review': 'Buat netizen yang ngemis2 ingin ada fitur story di Telegram, '
            'goblok klean, yg ada nanti 11-12 dgn WA...udah gausah ditambah '
            'fitur story...',
  'title': 'Jangan Tambahkan Fitur Story',
  'userName': 'Pitaloka Tan'},
 {'date': datetime.datetime(2021, 1, 31, 2, 27, 11),
  'isEdited': False,
  'rating': 5,
  'review': 'Kenapa sih org2 pada minta diadain story. Jgn min. Udah bagus '
            'gini. Kalo mau alay bikin stiry di wa sama ig aja udah.',
  'title': 'Gak jelas',
  'userName': 'fanfan1808'},
 {'date': datetime.datetime(2018, 10, 19, 8, 30, 33),
  'developerResponse': {'body': 'Sorry for the inconvenience. Can you please '
                                'update the app to the version 5.0.13. If the '
                                'app will continues crashing, please email us '
                                'qa@telegram.org, we need your help to fix the '
                                'problem.',
                        'id': 5647230,
                        'modified': '2018-10-24T14:48:25Z'},
  'isEdited': False,
  'rating': 1,
  'review': 'this app cant be opened since i made a group and wanted to change '
            'it to supergroup but suddenly this app closed and everytime i '
            'open it, it get closed. i already restart my phone and redownload '
            'it but still be the same when i login to my acc. help me.',
  'title': 'error',
  'userName': 'hyeolin'},
 {'date': datetime.datetime(2021, 3, 5, 2, 1, 9),
  'isEdited': False,
  'rating': 1,
  'review': 'For telegram, banyak akun bodong mengatas namakan BANK.... dan '
            'saya ketipu... Tolong ditangani!',
  'title': 'Penipuan',
  'userName': 'indahsisy'},
 {'date': datetime.datetime(2021, 5, 3, 12, 39, 14),
  'isEdited': False,
  'rating': 1,
  'review': 'Tidak bisa login setelah update, please fix it',
  'title': 'Gagal login',
  'userName': 'aaadevi'},
 {'date': datetime.datetime(2020, 3, 30, 18, 29, 15),
  'developerResponse': {'body': 'Hello. Sorry for the inconvenience. We’ve '
                                'fixed the issue in the new version 6.0.1 '
                                'released today. Please, update the app: '
                                'https://apps.apple.com/app/telegram-messenger/id686449807. ',
                        'id': 14394509,
                        'modified': '2020-04-01T17:36:25Z'},
  'isEdited': False,
  'rating': 3,
  'review': 'Why always force close after update ?',
  'title': 'Force close after update',
  'userName': 'AshaPlayer'},
 {'date': datetime.datetime(2022, 5, 8, 8, 59, 36),
  'isEdited': False,
  'rating': 4,
  'review': 'when i am open this apps, automatic close. Please Fix.',
  'title': 'IPHONE 6+ force close',
  'userName': 'hmdathiyyah'},
 {'date': datetime.datetime(2022, 5, 20, 20, 15, 24),
  'isEdited': False,
  'rating': 3,
  'review': 'Stuck on login screen, on screen text “ telegram dialed your '
            'number “ until 5 minute waiting there no code for entering '
            'telegram',
  'title': 'Bug',
  'userName': 'Priastana'},
 {'date': datetime.datetime(2022, 4, 8, 19, 9, 7),
  'isEdited': False,
  'rating': 1,
  'review': 'Masukin nomer ga ada sms sama sekali',
  'title': 'Eror',
  'userName': 'indahaprilia131313'},
 {'date': datetime.datetime(2021, 9, 6, 6, 9, 29),
  'isEdited': False,
  'rating': 1,
  'review': 'Terlalu banyak group telegram yang bersifat scam (penipuan) dan '
            'entah mengapa secara otomatis saya sudah didalam group tersebut. '
            'Saya berharap ada fitur untuk meminta izin saya terlebih dahulu '
            'sebelum secara otomatis dimasukkan ke dalam group di telegram. '
            'Mohon diperbaiki permasalahan ini.',
  'title': 'Banyak Group Scam !!!',
  'userName': 'al_fazri'},
 {'date': datetime.datetime(2020, 10, 6, 1, 50, 12),
  'isEdited': False,
  'rating': 5,
  'review': 'Kasih yang buat bikin story napa buat nak roleplayer hiks.',
  'title': 'Tambahan(?)',
  'userName': 'inibukanmia'},
 {'date': datetime.datetime(2021, 9, 6, 8, 40, 9),
  'isEdited': False,
  'rating': 1,
  'review': 'They create groups as large as 50,000 members and send thousands '
            'of messages. Reporting is difficult and obviously useless as how '
            'can accounts add so many members and send so many messages '
            'without being reported?',
  'title': 'Perfect for spammers',
  'userName': 'GillesJS'},
 {'date': datetime.datetime(2021, 7, 28, 13, 49, 33),
  'isEdited': False,
  'rating': 1,
  'review': 'so many spam at telegram add me to join trading grup plese add '
            'features to fix this problem, dont tell your app is secure if '
            'many spam everywere',
  'title': 'Spammer',
  'userName': 'ElGunawan'},
 {'date': datetime.datetime(2021, 1, 5, 15, 37, 43),
  'isEdited': False,
  'rating': 5,
  'review': 'film” lama & drakor lama lengkap disini bingung gatau lg gimana '
            'nemuinnya kalo ga nonton di tele 😭',
  'title': 'jgn di banned plis',
  'userName': 'zoypom'},
 {'date': datetime.datetime(2023, 1, 23, 12, 58, 27),
  'isEdited': False,
  'rating': 3,
  'review': 'Segera perbaiki bug!\n'
            'Jangan kasih fitur story atau fitur yang aneh aneh, telegram is '
            'the best untuk pesan yang sederhana dan private. Ty',
  'title': 'Bug issue',
  'userName': 'taufiqis'},
 {'date': datetime.datetime(2022, 9, 17, 21, 36, 45),
  'isEdited': False,
  'rating': 1,
  'review': '3 acc gua ke log out sendiri, gimana cara ngatasinnya please??? '
            'padahal gua sering on di acc tsb, kok bisa ya ke log out sendiri? '
            'padahal sebelum sebelum nya gapernah terjadi hal seperti ini',
  'title': 'minus',
  'userName': 'jalwjfowod'},
 {'date': datetime.datetime(2022, 9, 17, 13, 13, 55),
  'isEdited': False,
  'rating': 1,
  'review': 'kenapa akun saya ke banned terus ya? sudah 3x buat akun 3x juga '
            'kena banned',
  'title': 'Akun Ke Banned',
  'userName': 'bebe567bebe'},
 {'date': datetime.datetime(2022, 5, 10, 8, 11, 1),
  'isEdited': False,
  'rating': 2,
  'review': 'Gapernah dapet sms code buat login🙂',
  'title': 'Code',
  'userName': 'asdfrtyulkbgf'},
 {'date': datetime.datetime(2022, 5, 5, 1, 53, 11),
  'isEdited': False,
  'rating': 1,
  'review': 'Ini kenapa telegram ga bisa login, kode verifikasi ga masuk-masuk',
  'title': 'Keluhan',
  'userName': 'Maulana0000'},
 {'date': datetime.datetime(2022, 1, 12, 1, 11, 25),
  'isEdited': False,
  'rating': 1,
  'review': 'Tiba tiba kelogout sendiri! Padahal akunnya banyak data penting. '
            'Mana nomornya udah mati lagi',
  'title': 'Kelogout sendiri',
  'userName': 'nyxthr'},
 {'date': datetime.datetime(2021, 7, 14, 15, 28, 47),
  'isEdited': False,
  'rating': 1,
  'review': 'Banyak Penipuan , privasi kita tidak aman di telegram , lebih '
            'aman di whatsapp , instagram , facebook . \n'
            '\n'
            'Hampir saja data privasi (QR code) sy diambil alih oleh penipu '
            'untuk mencoba masuk terus , dengan mengaku dari telegram by phone '
            'minta code OTP . Harus sangat berhati hati di telegram yaa',
  'title': 'PENIPUAN',
  'userName': 'oshin topan'},
 {'date': datetime.datetime(2021, 4, 23, 5, 35, 5),
  'isEdited': False,
  'rating': 3,
  'review': 'Kenapa tiap kali aktivasi selalu dapt sms kode aktifasi dari '
            'nomor tak di kenal sebelum sms kode resmi dari tekegram masuk ?',
  'title': 'No kode dari no tak di kenal',
  'userName': 'gasssss10'},
 {'date': datetime.datetime(2023, 11, 24, 10, 51, 5),
  'isEdited': False,
  'rating': 5,
  'review': 'Lebih mudah menggunakan dan bisa juga mengirim video lebih '
            'panjang… good job',
  'title': 'Baik',
  'userName': 'Made natha'},
 {'date': datetime.datetime(2023, 11, 18, 16, 54, 5),
  'isEdited': False,
  'rating': 2,
  'review': 'kenapa ya di perangkat ios di bawah 17 tidak bisa membeli '
            'telegram premium tolong perbaiki terimakasih',
  'title': 'TIDAK BISA BELI TELEGRAM PREMIUM',
  'userName': 'Nabil Ramadhan'},
 {'date': datetime.datetime(2023, 11, 18, 10, 15, 46),
  'isEdited': False,
  'rating': 1,
  'review': 'Lots of bug, some video cant share to telegram. Data usage not '
            'accurate',
  'title': 'Failed send a video',
  'userName': 'Halca*Alane'},
 {'date': datetime.datetime(2023, 10, 19, 23, 57, 11),
  'isEdited': False,
  'rating': 1,
  'review': 'I CAN’T OPEN MY TELEGRAM PLEASE HELP.',
  'title': 'edogawaaaa',
  'userName': 'No4h_'},
 {'date': datetime.datetime(2023, 9, 2, 23, 11, 37),
  'isEdited': False,
  'rating': 4,
  'review': 'Add PiP (Picture in Picture) feature during video calls on '
            'Telegram.',
  'title': 'Add the feature of PiP for video call',
  'userName': 'Berrit Olam'},
 {'date': datetime.datetime(2023, 10, 6, 11, 27, 48),
  'isEdited': False,
  'rating': 1,
  'review': 'So much restrictions in this app, there is also a limit and buggy '
            'things that are certainly not being considered by the developer, '
            'rate ? ( -1/10 )',
  'title': 'Stories',
  'userName': 'Jef_89_2001'},
 {'date': datetime.datetime(2023, 10, 3, 15, 51, 33),
  'isEdited': False,
  'rating': 1,
  'review': 'woi gajelas, apasi telpon suka gada suaranya, bug mulu bug',
  'title': 'gj',
  'userName': 'bsiwiwb62626'},
 {'date': datetime.datetime(2023, 9, 29, 20, 25, 43),
  'isEdited': False,
  'rating': 1,
  'review': 'cant login,no message received when adding number to tele,no code '
            'received many times i tried still didnt work',
  'title': 'annoying',
  'userName': 'rTTaaRR'},
 {'date': datetime.datetime(2023, 9, 29, 4, 37, 39),
  'isEdited': False,
  'rating': 1,
  'review': 'nomor gue ke banned trs, pdhl gue login aja jarang. tb tb ke '
            'banned sndri! Tolong dong telegram kerjasama nya! APALAGI PAS MW '
            'LOGIN GA DI KSI KODE HDHH PDHL NO GAK MATI. TELE TLONG DONG '
            'KERJASAMA NYA! SY MOHON BGT KRN SY BTUH.',
  'title': 'nomor ke banned trus',
  'userName': 'kai_06'},
 {'date': datetime.datetime(2023, 9, 28, 15, 37, 2),
  'isEdited': False,
  'rating': 1,
  'review': 'gabisa log in padahal udah input nomor yg bener😭',
  'title': 'sad',
  'userName': 'shintarosalina'},
 {'date': datetime.datetime(2023, 9, 1, 14, 56, 5),
  'isEdited': False,
  'rating': 4,
  'review': 'Kenapa gabisa add story telegram ya? padahal sebagian yang ngga '
            'prem bisa',
  'title': 'Story Telegram',
  'userName': 'coc4ineee'},
 {'date': datetime.datetime(2023, 9, 1, 17, 34, 20),
  'isEdited': False,
  'rating': 1,
  'review': 'akun yg isinya tugas kuliah, file kerjaan, foto2 kenangan, dan '
            'semuanya ada ditelegram eh malah dihack sama orang yg ga '
            'bertanggung jawab, nangis sejadi jadinya pas tau akunya gabisa '
            'balik sakit hati bangett. kecewa sama telegram yg sekarang makin '
            'freak!',
  'title': 'HATE TELEGRAM!',
  'userName': 'bdiebfaia'},
 {'date': datetime.datetime(2023, 8, 24, 12, 19, 21),
  'isEdited': False,
  'rating': 3,
  'review': 'please. knp gabisa login? padahal nomer udh bener, tulisanny '
            'kirim code ny ke email pas di cek gaada code yng masuk. sampe udh '
            'di uninstall trus di download lagi tetep juga gabisa, tolong di '
            'perbaiki.',
  'title': 'gabisa login.',
  'userName': 'neirbulan'},
 {'date': datetime.datetime(2023, 8, 24, 16, 9, 10),
  'isEdited': False,
  'rating': 1,
  'review': 'kenapa gabisa log in ya',
  'title': 'Eror',
  'userName': 'prtmaa_'},
 {'date': datetime.datetime(2023, 8, 24, 15, 41, 13),
  'isEdited': False,
  'rating': 1,
  'review': 'INI GMNAA KAK? akuu mauu loginn gabisaa bisaaa😕😕buatt teleee '
            'tolongg dibpercepat yya perbaikan nyaa. akuu mauu log telee lg '
            'kakk plss plss😣😣👎👎',
  'title': 'forr telee',
  'userName': 'b!ell'},
 {'date': datetime.datetime(2023, 8, 10, 22, 33, 30),
  'isEdited': False,
  'rating': 1,
  'review': 'Udah nyoba berkali2 gabisa login ga dpt kode nya mlu 🤦🏻\u200d♀️',
  'title': 'Gabisa login',
  'userName': 'al aina al mardiah'},
 {'date': datetime.datetime(2023, 8, 10, 20, 8, 17),
  'isEdited': False,
  'rating': 1,
  'review': 'kok jadi susah login anj, tolol banget',
  'title': 'payah',
  'userName': 'juancokkk'},
 {'date': datetime.datetime(2023, 8, 9, 18, 5, 23),
  'isEdited': False,
  'rating': 1,
  'review': 'I cant login after accidentally tried to deleted my account once, '
            'and the system readt it like i deleted it so many times',
  'title': 'Can’t login',
  'userName': 'DjMarcell'},
 {'date': datetime.datetime(2023, 7, 29, 16, 50, 6),
  'isEdited': False,
  'rating': 1,
  'review': 'halo pihak telegram, ini acc gua ke ban terus ya? jujur gua cape '
            'ini acc ke ban terus,terus ganti acc yang lain. gua make nokos '
            'sampe 12x lebih kena banned terus. padahal gua ga ngapa ngapain, '
            'perbaiki tolong... kesian yang rugi ga cuman gua doang. makasih',
  'title': 'kenapa ke ban terus? gua cape',
  'userName': 'Hqhakhahhwa'},
 {'date': datetime.datetime(2023, 7, 22, 13, 21, 4),
  'isEdited': False,
  'rating': 1,
  'review': 'Malah makin gabisa login. Ribet segala make email segala macem ga '
            'dapet kode otp dari sms atau telepon, makin jelek',
  'title': 'm',
  'userName': 'whotfuare'},
 {'date': datetime.datetime(2023, 7, 21, 10, 15, 40),
  'isEdited': False,
  'rating': 1,
  'review': 'tolong fitur story nya jangan premium 🙏🏻',
  'title': '🙏🏻',
  'userName': 'nangseruierejdikd'},
 {'date': datetime.datetime(2023, 7, 20, 11, 33, 19),
  'isEdited': False,
  'rating': 1,
  'review': 'yang bener aja lah ya. lagi make tb tb keluar pas masukin no '
            'malah di ban padahal ga ngapa ngapain ! bener dah',
  'title': 'telegram gj',
  'userName': 'alysa sgl'},
 {'date': datetime.datetime(2023, 7, 19, 15, 55, 56),
  'isEdited': False,
  'rating': 1,
  'review': 'agak lain tele cuma d pake chat doang d banned, sehat kah ???',
  'title': 'akun di banned',
  'userName': 'badrunxxx'},
 {'date': datetime.datetime(2023, 7, 17, 15, 47, 52),
  'isEdited': False,
  'rating': 1,
  'review': 'Tele ajg ga ngotak apus aje bgst app tolol ga guna banyak penipu '
            'scam online pake ni app',
  'title': 'Aplikasitolol',
  'userName': 'korban scam tele'},
 {'date': datetime.datetime(2023, 2, 20, 0, 24, 6),
  'isEdited': False,
  'rating': 3,
  'review': 'SUMPAH, ini telegram kenapa sih, akun ku selalu aja limit apalagi '
            'kali ini gabisa chat orang sama chat di grup, padahal aku spam '
            'aja gaada, udh gitu kalo mau chat orang ya yang mau order jualan '
            'ku!',
  'title': 'damieee',
  'userName': 'putripcrmakiiii'},
 {'date': datetime.datetime(2023, 7, 15, 21, 35, 14),
  'isEdited': False,
  'rating': 1,
  'review': 'tele, jangan ban nomor gua lagi dong, udah 3 kali loh nomor gua '
            'di ban',
  'title': 'tele jangan ban nomor gua',
  'userName': 'alciiey'},
 {'date': datetime.datetime(2023, 6, 21, 7, 45, 8),
  'isEdited': False,
  'rating': 1,
  'review': 'Aneh bgt tiba tiba gak bisa kirim pesan ke orang baru hadeh gagal '
            'semua lagi. Tolong perbaiki segera bug nya',
  'title': 'Gagal kirim pesan',
  'userName': 'Indriana pratiwi'},
 {'date': datetime.datetime(2023, 4, 5, 19, 31, 37),
  'isEdited': False,
  'rating': 1,
  'review': 'mohon maaf pihak telegram, ko setiap kali saya bikin akun selalu '
            'kena ban? padahal saya ga aneh aneh loh, udah habis hampir 8 '
            'nomer selalu kena ban',
  'title': 'selalu kena ban',
  'userName': 'alfadri'},
 {'date': datetime.datetime(2023, 3, 5, 20, 10, 18),
  'isEdited': False,
  'rating': 1,
  'review': 'When im starting to play anonymous chat, im always got banned as '
            'a spam, but actually im NOT, please fix this bug, i cant even can '
            'do chatting with strangers peacefully',
  'title': 'im always got banned as a spam',
  'userName': 'Pollcarpus'},
 {'date': datetime.datetime(2023, 1, 2, 7, 28, 51),
  'isEdited': False,
  'rating': 5,
  'review': 'telegram i have some problem, can u send code verivication by sms '
            'again? i cant use my email,or can i report my problem? please..',
  'title': 'help me telegram',
  'userName': 'craramel'},
 {'date': datetime.datetime(2023, 2, 19, 12, 16, 10),
  'isEdited': False,
  'rating': 1,
  'review': 'please stop banning my account, i didn’t even do anything wrong 😕 '
            'i’ll never use telegram no more.',
  'title': 'banned account',
  'userName': 'sdhffbdn'},
 {'date': datetime.datetime(2023, 2, 18, 4, 15, 46),
  'isEdited': False,
  'rating': 1,
  'review': 'WTH 😂',
  'title': 'Request OTP resend via compose an email?',
  'userName': 'deo_rayyan'},
 {'date': datetime.datetime(2023, 2, 6, 2, 47, 30),
  'isEdited': False,
  'rating': 1,
  'review': 'Udah 8x ya akun saya kebanned, dengan 7 nomor yg berbeda. '
            'Salahnya dimana? Kasih tau!!! Aswww',
  'title': 'ASW BANNED TEROS',
  'userName': 'JAMES BUCKYYY'},
 {'date': datetime.datetime(2023, 2, 2, 12, 49, 44),
  'isEdited': False,
  'rating': 1,
  'review': 'tele skrg hobi ngebanned nomer ya? belum sebulan 7 nomer ke '
            'banned, pls lah 😔😔',
  'title': 'banned',
  'userName': 'siesaga'},
 {'date': datetime.datetime(2023, 2, 2, 12, 24, 1),
  'isEdited': False,
  'rating': 1,
  'review': 'masa tiba2 ke banned padahal cuma buat chat grup aja pas mau buka '
            'telegram nya malah ke banned aneh banget',
  'title': 'ke banned tanpa sebab',
  'userName': 'R4jabjuzman'},
 {'date': datetime.datetime(2023, 1, 26, 14, 38, 59),
  'isEdited': False,
  'rating': 2,
  'review': 'Makin aneh aja telegram, giliran dihapus video yg udah didowload '
            'malah gak bisa ttap ada video nya, kembalikan dong kek dulu, '
            'habis update bukannya bagus malah makin jelek.. gimana sihh',
  'title': 'Jelek',
  'userName': 'Molen95'},
 {'date': datetime.datetime(2022, 6, 1, 11, 28, 15),
  'isEdited': False,
  'rating': 5,
  'review': 'Can you di starred messages like whatsapp? Sometimes in some '
            'channels i’d like to star the messages to be read later or as a '
            'reminder. \n'
            '\n'
            'Thx.',
  'title': 'Starred messages',
  'userName': 'Untuunggg'},
 {'date': datetime.datetime(2022, 6, 23, 20, 5, 24),
  'isEdited': False,
  'rating': 2,
  'review': 'Gini aja udah bagus kok pertahankan, cukup nge story di wa sama '
            'ig aja, telegram kagak usah dah',
  'title': 'Gak usah ada fitur story',
  'userName': 'maaf kan'},
 {'date': datetime.datetime(2022, 5, 30, 12, 59, 12),
  'isEdited': False,
  'rating': 5,
  'review': 'gausaa, lo pada kalo mau pake story gitu langsung aje ke apps '
            'sebelah, gajelas',
  'title': 'gausa buat story”an',
  'userName': 'gkhua'},
 {'date': datetime.datetime(2022, 5, 29, 10, 23, 34),
  'isEdited': False,
  'rating': 5,
  'review': 'Its perfect app.',
  'title': "PLEASE DON'T EVER MAKE STORIES FEATURE",
  'userName': 'ianR2'},
 {'date': datetime.datetime(2022, 4, 8, 13, 57, 42),
  'isEdited': False,
  'rating': 5,
  'review': 'Keep stable and make secure traffic in next update',
  'title': 'Nothing change’s',
  'userName': 'Ashr.mine'},
 {'date': datetime.datetime(2022, 5, 8, 8, 11, 46),
  'isEdited': False,
  'rating': 1,
  'review': 'Why i can’t watching movie ?? \n\U0001fae4\U0001fae4\U0001fae4',
  'title': 'Why?',
  'userName': 'putciputtttt'},
 {'date': datetime.datetime(2022, 4, 8, 18, 27, 20),
  'isEdited': False,
  'rating': 1,
  'review': 'This is so annoying, I didn’t receive any new messages until I '
            'open the telegram app. Please fix this. This problem didn’t '
            'ococured on other messaging services or social media.',
  'title': 'New messages won’t appears until I open the app',
  'userName': 'Bluehg'},
 {'date': datetime.datetime(2022, 4, 8, 2, 54, 26),
  'isEdited': False,
  'rating': 1,
  'review': 'Can’t receive OTP code over sms or call',
  'title': 'OTP doesn’t work',
  'userName': 'Aryodwin'},
 {'date': datetime.datetime(2021, 9, 14, 11, 25, 34),
  'isEdited': False,
  'rating': 4,
  'review': 'You should stop to tell me who else joined. This is serious '
            'problem.',
  'title': 'Stop tell me.',
  'userName': 'elwoodcon scher'},
 {'date': datetime.datetime(2022, 3, 16, 10, 0, 31),
  'isEdited': False,
  'rating': 5,
  'review': 'Egk usah pake fitur story”an ,cukup gini aja udah 👍',
  'title': '❤️',
  'userName': 'gndrng1'},
 {'date': datetime.datetime(2022, 3, 13, 6, 15, 20),
  'isEdited': False,
  'rating': 3,
  'review': 'suka error kalau mau kirim pesan, pesan gak ke kirim bikin kesel',
  'title': 'error',
  'userName': 'bshsnajsbajabaj'},
 {'date': datetime.datetime(2022, 3, 9, 9, 27, 46),
  'isEdited': False,
  'rating': 3,
  'review': 'My iphone se 2020 with latest update having issue when using '
            'secret chat. It automatically force closed and not able to open '
            'telegram anymore. Every open it always force close. So currently '
            'i only able open telegram by desktop app.',
  'title': 'Force close secret chat in Iphone',
  'userName': 'Randy Mukti'},
 {'date': datetime.datetime(2022, 3, 9, 5, 23, 47),
  'isEdited': False,
  'rating': 2,
  'review': 'Ini kenapa ya kok gabisa login sih padahal udah masukin nomor nya '
            'tapi gak di sms sms ya',
  'title': 'tolong diperbaiki',
  'userName': 'adam pasah'},
 {'date': datetime.datetime(2022, 2, 3, 7, 54, 48),
  'isEdited': False,
  'rating': 1,
  'review': 'Kok tele ny jd gini si stlh di update????',
  'title': '.',
  'userName': 'Jihan L.A.'},
 {'date': datetime.datetime(2022, 2, 1, 9, 26, 48),
  'isEdited': False,
  'rating': 1,
  'review': 'Why can’t i access my telegram after update the app? It keep '
            'close forcing everytime i want to open chat',
  'title': 'Close force',
  'userName': 'rzitshvir'},
 {'date': datetime.datetime(2022, 1, 9, 0, 52, 14),
  'isEdited': False,
  'rating': 1,
  'review': 'Saya tidak suka fitur baru pada telegram. Yang mana ada '
            'chanel/grup yang tidak dapat menyimpan file video. Saya download '
            'dulu videonya dan bermaksud di tonton nanti dan kelupaan '
            'mengaktifkan fitur hapus penyimpanan selama 3 hari dan otomatis '
            'fipe video yang berukuran besar pun lenyap. Namun kalau saya '
            'tidak mengaktifkan fitur hapus data selama 3 hari  penyimpanan '
            'saya habis membengkak. Kalau ada fitur save video saya bisa '
            'pindahkan filenya videonya ke pc dan di hapus di telegram',
  'title': 'Hate new features',
  'userName': 'Rivalous'},
 {'date': datetime.datetime(2021, 12, 23, 14, 34, 22),
  'isEdited': False,
  'rating': 1,
  'review': 'Pengembang telegram agar membuat sistem pengamanan dari grup2 '
            'sampah investasi yg masuk otomatis, ini sangat menggangu privasi '
            'pengguna telegram.',
  'title': 'Tidak ada privasi, grup sampah masuk otomatis',
  'userName': '123bgkhh'},
 {'date': datetime.datetime(2021, 12, 10, 7, 36, 34),
  'isEdited': False,
  'rating': 1,
  'review': 'Sebelum ada pembaruan oke tidak ada masalah, setelah di perbarui '
            'tdk bisa login responnya karna masalah koneksi. Tolong di '
            'perbaiki',
  'title': 'Koneksi terputus',
  'userName': 'uchatttt'},
 {'date': datetime.datetime(2021, 12, 10, 3, 58, 21),
  'isEdited': False,
  'rating': 1,
  'review': 'Tolong perbaiki dong pihak instagram setelah download lagi malah '
            'ga bisa dibuka servernya bukan indonesia 😭😭',
  'title': 'Kecewa banget',
  'userName': 'zafketyi'},
 {'date': datetime.datetime(2021, 11, 21, 3, 2, 58),
  'isEdited': False,
  'rating': 5,
  'review': 'despite some people requesting, it please please please keep '
            'telegram this way and not add the story feature! the reason why i '
            "(and i'm sure a lot others) like telegram so much is because of "
            "this very reason. we don't need stories everywhere thank you very "
            'much! those who want stories can go to instagram or whatsapp etc.',
  'title': 'NO STORIES PLEASE',
  'userName': 'Ppm19'},
 {'date': datetime.datetime(2021, 11, 7, 10, 55, 57),
  'isEdited': False,
  'rating': 2,
  'review': 'saya tidak bisa download video nya ,',
  'title': 'tidak bisa download',
  'userName': 'diah afriza'},
 {'date': datetime.datetime(2021, 11, 7, 7, 58, 20),
  'isEdited': False,
  'rating': 2,
  'review': 'Why do i can’t download the video even the wifi/cellular '
            'networking is very good and too much available space. Please fix '
            'the issues. Thank you',
  'title': 'Can’t download Video',
  'userName': 'Pisces100499'},
 {'date': datetime.datetime(2021, 10, 24, 14, 21, 18),
  'isEdited': False,
  'rating': 1,
  'review': 'saat mau masuk telegram ada tulisan “nomer ponsel ini diblokir” '
            'tolong pihak telegram membuka lagi akun saya ada orang dengan '
            'sengaja melaporkan saya',
  'title': 'tolong lepas blokir saya',
  'userName': 'pajarroii'},
 {'date': datetime.datetime(2021, 10, 24, 13, 1, 24),
  'isEdited': False,
  'rating': 1,
  'review': 'Whats wrong telegram, i cant save my downloaded video on my '
            'gallery anymore. And if i try to watch the video its stop like 3s '
            'after i loaded it . Please fix it!!',
  'title': 'Cant save video and load it',
  'userName': 'reikaze 22'},
 {'date': datetime.datetime(2021, 10, 21, 2, 48, 58),
  'isEdited': False,
  'rating': 5,
  'review': 'Mau tanya aja telegram memang sering adain bagi” voucher pulsa '
            'lewat wa yah?',
  'title': 'Mau bertanya',
  'userName': 'kdlxksnoasn'},
 {'date': datetime.datetime(2021, 9, 22, 19, 15, 55),
  'isEdited': False,
  'rating': 5,
  'review': 'Don’t make snap telegram fiture, please. Telegram already the '
            'best application, it’s different with other apps. I love it, '
            'cause this app doesn’t have snap/stories fiture. I ALREADY LOVE '
            'TELEGRAM CAUSE IT’S NOT LIKE OTHER SOCIAL MEDIA APPLICATIONS. So, '
            'you don’t have to add that fiture.',
  'title': 'Please don’t, cause this app is good enough.',
  'userName': 'your app is error.'},
 {'date': datetime.datetime(2021, 9, 16, 4, 44, 37),
  'isEdited': False,
  'rating': 2,
  'review': "What is wrong with Telegram? I've turned off the Find People "
            'Nearby feature and made my account invisible. But still, many '
            'unknown people from nearby sent messages. Please work on it! It '
            'is so disturbing!',
  'title': 'Disturbing',
  'userName': 'Lovely Lulaby'},
 {'date': datetime.datetime(2021, 9, 2, 15, 38, 23),
  'isEdited': False,
  'rating': 1,
  'review': 'Keeps crashing after latest update',
  'title': 'Keeps crashing',
  'userName': 'geksing'}
]

# Specify the CSV file name
csv_file = "telegram_review_test.csv"

# Define the field names (column names) based on the keys in your dictionaries
#field_names = data[0].keys()
field_names = ['date', 'isEdited', 'rating', 'review', 'title', 'userName', 'developerResponse']

# Write the data to the CSV file
with open(csv_file, mode='w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=field_names)

    # Write the header (field names)
    writer.writeheader()

    # Write the data rows
    for row in data:
        writer.writerow(row)

print(f"Data has been written to {csv_file}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3a041a827bbf> in <cell line: 759>()
#     758 # Write the data to the CSV file
#     759 with open(csv_file, mode='w', newline='') as file:
# --> 760     writer = csv.DictWriter(file, fieldnames=field_names)
#     761
#     762     # Write the header (field names)
#
# NameError: name 'csv' is not defined
